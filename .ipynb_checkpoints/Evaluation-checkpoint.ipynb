# %% [markdown]
# # Runtime： 1.5s-1.9s

# %%
import numpy as np
from scipy import special
import os
import pandas as pd

# %%
df = pd.read_csv('output/summary.tsv', sep='\t')

# %%
df = df[df.accuracy != 0]

# %%
df_mean = df.groupby('parameters').mean()

# %%
df_se = df.groupby('parameters').sem()

# %%
df = df.groupby('parameters').agg(['mean','sem'])
df.columns = df.columns.map('_'.join)
df.reset_index()
# Out:
#           parameters  trial_id_mean  trial_id_sem  accuracy_mean  \
# 0    param[1, 7, 10]       4.500000      1.554563       0.100000
# 1  param[1.5, 6, 10]       5.000000      2.645751       0.166667
# 2  param[1.5, 7, 10]       4.200000      1.157584       0.220000
# 3  param[1.5, 7, 20]       4.428571      1.324803       0.350000
# 4   param[1.5, 7, 5]       3.000000      2.000000       0.200000
# 5  param[1.5, 8, 10]       3.166667      1.194897       0.183333
# 6    param[2, 7, 10]       5.666667      1.333333       0.366667
#
#    accuracy_sem  correct_pos_predicted_mean  correct_pos_predicted_sem  \
# 0      0.000000                    1.000000                   0.000000
# 1      0.066667                    1.666667                   0.666667
# 2      0.048990                    2.200000                   0.489898
# 3      0.074001                    7.000000                   1.480026
# 4      0.000000                    1.000000                   0.000000
# 5      0.065405                    1.833333                   0.654047
# 6      0.095452                    3.666667                   0.954521
#
#    correct_sites_predicted_mean  correct_sites_predicted_sem  kl_dis_mean  \
# 0                      1.250000                     1.250000    35.083842
# 1                      6.333333                     0.881917     9.386196
# 2                      3.000000                     1.140175    21.261949
# 3                     11.285714                     2.446711     8.101220
# 4                      0.000000                     0.000000    35.599261
# 5                      3.500000                     1.204159    26.803999
# 6                      3.833333                     1.301708    19.954961
#
#    kl_dis_sem
# 0    4.808443
# 1    1.679662
# 2    8.106384
# 3    1.626485
# 4    0.105900
# 5    4.925483
# 6    6.491653

# %%
lines = df.plot.line(y=['accuracy_mean','accuracy_sem'],figsize=(10,5),title='Accuracy(Number of overlapping positions/Number of sequence)')

# %%
lines = df.plot.line(y=['correct_pos_predicted_mean','correct_pos_predicted_sem'],figsize=(10,5),title='Number of overlapping positions')

# %%
lines = df.plot.line(y=['correct_sites_predicted_mean','correct_sites_predicted_sem'],figsize=(10,5),title='Number of overlapping sites')

# %%
lines = df.plot.line(y=['kl_dis_mean','kl_dis_sem'],figsize=(10,5),title='Kullback-Leibler (KL) divergence')

# %%
df_mean
# Out:
#                    trial_id  accuracy  correct_pos_predicted  \
# parameters
# param[1, 7, 10]    4.500000  0.100000               1.000000
# param[1.5, 6, 10]  5.000000  0.166667               1.666667
# param[1.5, 7, 10]  4.200000  0.220000               2.200000
# param[1.5, 7, 20]  4.428571  0.350000               7.000000
# param[1.5, 7, 5]   3.000000  0.200000               1.000000
# param[1.5, 8, 10]  3.166667  0.183333               1.833333
# param[2, 7, 10]    5.666667  0.366667               3.666667
#
#                    correct_sites_predicted     kl_dis
# parameters
# param[1, 7, 10]                   1.250000  35.083842
# param[1.5, 6, 10]                 6.333333   9.386196
# param[1.5, 7, 10]                 3.000000  21.261949
# param[1.5, 7, 20]                11.285714   8.101220
# param[1.5, 7, 5]                  0.000000  35.599261
# param[1.5, 8, 10]                 3.500000  26.803999
# param[2, 7, 10]                   3.833333  19.954961

# %%
df_se
# Out:
#                    trial_id  accuracy  correct_pos_predicted  \
# parameters
# param[1, 7, 10]    1.554563  0.000000               0.000000
# param[1.5, 6, 10]  2.645751  0.066667               0.666667
# param[1.5, 7, 10]  1.157584  0.048990               0.489898
# param[1.5, 7, 20]  1.324803  0.074001               1.480026
# param[1.5, 7, 5]   2.000000  0.000000               0.000000
# param[1.5, 8, 10]  1.194897  0.065405               0.654047
# param[2, 7, 10]    1.333333  0.095452               0.954521
#
#                    correct_sites_predicted    kl_dis
# parameters
# param[1, 7, 10]                   1.250000  4.808443
# param[1.5, 6, 10]                 0.881917  1.679662
# param[1.5, 7, 10]                 1.140175  8.106384
# param[1.5, 7, 20]                 2.446711  1.626485
# param[1.5, 7, 5]                  0.000000  0.105900
# param[1.5, 8, 10]                 1.204159  4.925483
# param[2, 7, 10]                   1.301708  6.491653
